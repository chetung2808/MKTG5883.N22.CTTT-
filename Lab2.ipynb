# %%
# %matplotlib inline
import numpy as np
import pandas as pd

df= pd.read_csv("./drive/MyDrive/Colab/PastHires.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import numpy as np
#       3 import pandas as pd
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:2414, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2412     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2413 with self.builtin_trap:
# -> 2414     result = fn(*args, **kwargs)
#    2416 # The code below prevents the output from being displayed
#    2417 # when using magics with decodator @output_can_be_silenced
#    2418 # when the last Python token in the expression is a ';'.
#    2419 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
df.head(10)
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
# 5                 0         N                   0                PhD
# 6                 5         Y                   2                 MS
# 7                 3         N                   1                 BS
# 8                15         Y                   5                 BS
# 9                 0         N                   0                 BS
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N
# ...

# %%
df.tail(4)
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# 12                 0         N                   0                PhD
#
#    Top-tier school Interned Hired
# 9                N        N     N
# 10               Y        N     N
# 11               N        Y     Y
# 12               Y        N     Y

# %%
df.shape
# Out:
# (13, 7)

# %%
df.size
# Out:
# 91

# %%
len(df)
# Out:
# 13

# %%
df.columns
# Out:
# Index(['Years Experience', 'Employed?', 'Previous employers',
#        'Level of Education', 'Top-tier school', 'Interned', 'Hired'],
#       dtype='object')

# %%
df['Hired']
# Out:
# 0     Y
# 1     Y
# 2     N
# 3     Y
# 4     N
# 5     Y
# 6     Y
# 7     Y
# 8     Y
# 9     N
# 10    N
# 11    Y
# 12    Y
# Name: Hired, dtype: object

# %%
df['Hired'][:5]
# Out:
# 0    Y
# 1    Y
# 2    N
# 3    Y
# 4    N
# Name: Hired, dtype: object

# %%
df['Hired'][5]
# Out:
# 'Y'

# %%
df[['Years Experience', 'Hired']]
# Out:
#     Years Experience Hired
# 0                 10     Y
# 1                  0     Y
# 2                  7     N
# 3                  2     Y
# 4                 20     N
# 5                  0     Y
# 6                  5     Y
# 7                  3     Y
# 8                 15     Y
# 9                  0     N
# 10                 1     N
# 11                 4     Y
# 12                 0     Y

# %%
df[['Years Experience', 'Hired']][:5]
# Out:
#    Years Experience Hired
# 0                10     Y
# 1                 0     Y
# 2                 7     N
# 3                 2     Y
# 4                20     N

# %%
df.sort_values(['Years Experience'])
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 1                  0         N                   0                 BS
# 5                  0         N                   0                PhD
# 9                  0         N                   0                 BS
# 12                 0         N                   0                PhD
# 10                 1         N                   1                PhD
# 3                  2         Y                   1                 MS
# 7                  3         N                   1                 BS
# 11                 4         Y                   1                 BS
# 6                  5         Y                   2                 MS
# 2                  7         N                   6                 BS
# 0                 10         Y                   4                 BS
# 8                 15         Y                   5                 BS
# ...

# %%
degree_counts = df['Level of Education'].value_counts()
degree_counts
# Out:
# BS     7
# PhD    4
# MS     2
# Name: Level of Education, dtype: int64

# %%
degree_counts.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# II. Series

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Creating a Series

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %% [markdown]
# Using Lists

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# NumPy Arrays

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# Dictionary

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# 2. Data in Series

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %% [markdown]
# 3. Using an index

# %%
ser1 = pd.Series([1,2,3,4],index = ['USA', 'Germany','USSR', 'Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','Italy', 'Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# 1

# %%
ser1 + ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %% [markdown]
# III. DataFrames

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# 1. Selection and Indexing

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df.W
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %%
df.loc['B','Y']
# Out:
# -0.8480769834036315

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %% [markdown]
# 2. Conditional Selection

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0]['Y']
# Out:
# A    0.907969
# B   -0.848077
# D   -0.933237
# E    2.605967
# Name: Y, dtype: float64

# %%
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# A  0.907969  0.628133
# B -0.848077 -0.319318
# D -0.933237 -0.758872
# E  2.605967  1.978757

# %%
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# 3. More Index Details

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
newind = 'CA NY WY OR CO'.split()

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('States',inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# 4. Multi-Index and Index Hierarchy

# %%
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df
# Out:
#              A         B
# G1 1  0.302665  1.693723
#    2 -1.706086 -1.159119
#    3 -0.134841  0.390528
# G2 1  0.166905  0.184502
#    2  0.807706  0.072960
#    3  0.638787  0.329646

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.302665  1.693723
# 2 -1.706086 -1.159119
# 3 -0.134841  0.390528

# %%
df.loc['G1'].loc[1]
# Out:
# A    0.302665
# B    1.693723
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1    0.302665  1.693723
#       2   -1.706086 -1.159119
#       3   -0.134841  0.390528
# G2    1    0.166905  0.184502
#       2    0.807706  0.072960
#       3    0.638787  0.329646

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.302665  1.693723
# 2   -1.706086 -1.159119
# 3   -0.134841  0.390528

# %%
df.xs(['G1',1])
# Out:
# <ipython-input-463-c549ee06ce91>:1: FutureWarning: Passing lists as key for xs is deprecated and will be removed in a future version. Pass key as a tuple instead.
#   df.xs(['G1',1])
# A    0.302665
# B    1.693723
# Name: (G1, 1), dtype: float64

# %%
df.xs(1,level='Num')
# Out:
#               A         B
# Group
# G1     0.302665  1.693723
# G2     0.166905  0.184502

# %% [markdown]
# IV. Missing Data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# 1. GroupBy

# %%
import pandas as pd
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.groupby('Company')

# %%
by_comp = df.groupby("Company")

# %%
by_comp.mean()
# Out:
# <ipython-input-478-15ce3fbdee9c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_comp.mean()
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby('Company').mean()
# Out:
# <ipython-input-479-09ffb8aea42a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Company').mean()
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
by_comp.std()
# Out:
# <ipython-input-480-795bdc0ea79d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_comp.std()
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
by_comp.describe().transpose()['GOOG']
# Out:
# Sales  count      2.000000
#        mean     160.000000
#        std       56.568542
#        min      120.000000
#        25%      140.000000
#        50%      160.000000
#        75%      180.000000
#        max      200.000000
# Name: GOOG, dtype: float64

# %% [markdown]
# V. Merging, Joining and Concatenating

# %% [markdown]
# 1. Concatenation

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# 2. Merging

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left, right, how='outer', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(left, right, how='right', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %% [markdown]
# 3. Joining

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# VI. Operations

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# 1. Info on Unique Values

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %% [markdown]
# 2. Selecting Data

# %%
newdf = df[(df['col1']>2) & (df['col2']==444)]

# %%
newdf
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %% [markdown]
# 3. Applying Functions

# %%
def times2(x):
    return x*2

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col1'].sum()
# Out:
# 10

# %%
del df['col1']

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.columns
# Out:
# Index(['col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.sort_values(by='col2')
# Out:
#    col2 col3
# 0   444  abc
# 3   444  xyz
# 1   555  def
# 2   666  ghi

# %%
df.isnull()
# Out:
#     col2   col3
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False

# %%
df.dropna()
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.fillna('FILL')
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A', 'B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %% [markdown]
# VII. Data Input and Output

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. CSV

# %%
df= pd.read_csv("/example.csv")
df.head()
# Out:
#    Apple  Banana  Beans  Broccoli  Carrots  Mango  Orange  Grand Total
# 0      4      10    3.0         2      3.0    2.0       3           27
# 1      6       7    NaN         3      NaN    1.0       3           20
# 2     16       7    1.0         1      1.0    1.0       1           28
# 3      2       9    6.0         8      6.0    1.0       1           33
# 4      2       8    NaN         1      NaN    NaN       3           14

# %%
df = df.dropna()

# %%
df.to_csv('example',index=False)

# %% [markdown]
# 2. Excel

# %%
pd.read_excel('/example_data.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0  Apple  Banana  Beans  Broccoli  Carrots  Mango  Orange  \
# 0           0      4      10    3.0         2      3.0    2.0       3
# 1           1      6       7    NaN         3      NaN    1.0       3
# 2           2     16       7    1.0         1      1.0    1.0       1
# 3           3      2       9    6.0         8      6.0    1.0       1
# 4           4      2       8    NaN         1      NaN    NaN       3
# 5           5      4       7    2.0         8      7.0    1.0       5
# 6           6      6      23    1.0         4     10.0    5.0       8
# 7           7     40      71   13.0        27     27.0   11.0      24
#
#    Grand Total
# 0           27
# 1           20
# 2           28
# 3           33
# 4           14
# 5           34
# 6           57
# 7          213

# %%
df.to_excel('/example_data.xlsx',sheet_name='Sheet1')

# %%
df = df.dropna()

# %%
df.dtypes
# Out:
# Apple            int64
# Banana           int64
# Beans          float64
# Broccoli         int64
# Carrots        float64
# Mango          float64
# Orange           int64
# Grand Total      int64
# dtype: object

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('data',engine)
# Out:
# 6

# %%
sql_df = pd.read_sql('data', con=engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-615-3e105996ff79> in <cell line: 1>()
# ----> 1 sql_df = pd.read_sql('data', con=engine)
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     579         Data type for data or columns. E.g. np.float64 or
#     580         {‘a’: np.float64, ‘b’: np.int32, ‘c’: ‘Int64’}.
# --> 581         The argument is ignored if a table is passed instead of a query.
#     582
#     583         .. versionadded:: 2.0.0
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/sql.py in read_table(self, table_name, index_col, coerce_float, parse_dates, columns, schema, chunksize)
#    1458         try:
#    1459             return table.insert(chunksize=chunksize, method=method)
# -> 1460         except exc.StatementError as err:
# ...

# %%
sql_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-566-95225515a3de> in <cell line: 1>()
# ----> 1 sql_df
#
# NameError: name 'sql_df' is not defined

# %% [markdown]
# VIII. Exersises

# %% [markdown]
# 1

# %%
df= pd.read_csv("./drive/MyDrive/Colab/sales.csv")
df.head()
# Out:
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54  $2.50         2
# 3     10001                        NaN  2018-01-01 12:14:54  $1.50         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54  $3.50         1
#
#   line_total
# 0     $10.50
# 1      $3.50
# 2      $5.00
# 3      $1.50
# 4      $3.50

# %% [markdown]
# Fix column datatypes

# %%
df.head()
# Out:
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54  $2.50         2
# 3     10001                        NaN  2018-01-01 12:14:54  $1.50         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54  $3.50         1
#
#   line_total
# 0     $10.50
# 1      $3.50
# 2      $5.00
# 3      $1.50
# 4      $3.50

# %%
df.head()
# Out:
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54  $2.50         2
# 3     10001                        NaN  2018-01-01 12:14:54  $1.50         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54  $3.50         1
#
#   line_total
# 0     $10.50
# 1      $3.50
# 2      $5.00
# 3      $1.50
# 4      $3.50

# %%
df.dtypes
# Out:
# order_id       int64
# name          object
# ordered_at    object
# price         object
# quantity       int64
# line_total    object
# dtype: object

# %%
df['amount'] = df['price'].str.replace('$', '').astype(float)
df.head(10)
# Out:
# <ipython-input-265-17d5508a7983>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['amount'] = df['price'].str.replace('$', '').astype(float)
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54  $2.50         2
# 3     10001                        NaN  2018-01-01 12:14:54  $1.50         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54  $3.50         1
# 5     10002            "SORBET" Lychee  2018-01-01 12:23:09  $3.00         1
# 6     10002                        NaN  2018-01-01 12:23:09  $3.00         3
# ...

# %%
df = df.drop('price', axis=1)

# %%
df.rename(columns = {'amount':'price'}, inplace = True)

# %%
df.head(10)
# Out:
#    order_id                       name           ordered_at  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54         2
# 3     10001                        NaN  2018-01-01 12:14:54         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54         1
# 5     10002            "SORBET" Lychee  2018-01-01 12:23:09         1
# 6     10002                        NaN  2018-01-01 12:23:09         3
# 7     10002      "ICE CREAM" Earl Gray  2018-01-01 12:23:09         3
# 8     10003         "ICE CREAM" Matcha  2018-01-01 12:49:35         3
# 9     10004     "BEVERAGE" Iced Coffee  2018-01-01 13:22:59         2
#
#   line_total  price
# 0     $10.50    3.5
# 1      $3.50    3.5
# 2      $5.00    2.5
# 3      $1.50    1.5
# 4      $3.50    3.5
# 5      $3.00    3.0
# 6      $9.00    3.0
# 7      $1.50    0.5
# ...

# %%
moving_column = df.pop('price')
df.insert(3, 'price', moving_column)
df.head(10)
# Out:
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00    3.5         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00    3.5         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54    2.5         2
# 3     10001                        NaN  2018-01-01 12:14:54    1.5         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54    3.5         1
# 5     10002            "SORBET" Lychee  2018-01-01 12:23:09    3.0         1
# 6     10002                        NaN  2018-01-01 12:23:09    3.0         3
# 7     10002      "ICE CREAM" Earl Gray  2018-01-01 12:23:09    0.5         3
# 8     10003         "ICE CREAM" Matcha  2018-01-01 12:49:35    1.5         3
# 9     10004     "BEVERAGE" Iced Coffee  2018-01-01 13:22:59    2.5         2
#
#   line_total
# 0     $10.50
# 1      $3.50
# 2      $5.00
# 3      $1.50
# 4      $3.50
# 5      $3.00
# 6      $9.00
# ...

# %%
df['total'] = df['line_total'].str.replace('$', '').astype(float)
df.head(10)
# Out:
# <ipython-input-270-cf54e0ac585d>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['total'] = df['line_total'].str.replace('$', '').astype(float)
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00    3.5         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00    3.5         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54    2.5         2
# 3     10001                        NaN  2018-01-01 12:14:54    1.5         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54    3.5         1
# 5     10002            "SORBET" Lychee  2018-01-01 12:23:09    3.0         1
# 6     10002                        NaN  2018-01-01 12:23:09    3.0         3
# ...

# %%
df = df.drop('line_total', axis=1)

# %%
df.rename(columns = {'total':'line_total'}, inplace = True)
df.head(10)
# Out:
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00    3.5         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00    3.5         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54    2.5         2
# 3     10001                        NaN  2018-01-01 12:14:54    1.5         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54    3.5         1
# 5     10002            "SORBET" Lychee  2018-01-01 12:23:09    3.0         1
# 6     10002                        NaN  2018-01-01 12:23:09    3.0         3
# 7     10002      "ICE CREAM" Earl Gray  2018-01-01 12:23:09    0.5         3
# 8     10003         "ICE CREAM" Matcha  2018-01-01 12:49:35    1.5         3
# 9     10004     "BEVERAGE" Iced Coffee  2018-01-01 13:22:59    2.5         2
#
#    line_total
# 0        10.5
# 1         3.5
# 2         5.0
# 3         1.5
# 4         3.5
# 5         3.0
# ...

# %%
df.dtypes
# Out:
# order_id        int64
# name           object
# ordered_at     object
# price         float64
# quantity        int64
# line_total    float64
# dtype: object

# %% [markdown]
# Drop if duplicated or null.

# %%
df.isna().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# order_id      0
# name          0
# ordered_at    0
# price         0
# quantity      0
# line_total    0
# dtype: int64

# %%
if any(df['price'] < 0):
    print('Error: values outside expected range')
# Out:
# Error: values outside expected range

# %%
df = df.drop(df[df['price'] < 0].index)

# %%
if any(df['price'] < 0):
    print('Error: values outside expected range')

# %%
df
# Out:
#        order_id                       name           ordered_at  price  \
# 0         10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00    3.5
# 1         10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00    3.5
# 2         10001         "SORBET" Raspberry  2018-01-01 12:14:54    2.5
# 4         10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54    3.5
# 5         10002            "SORBET" Lychee  2018-01-01 12:23:09    3.0
# ...         ...                        ...                  ...    ...
# 29817     19997         "CONE" Waffle Cone  2018-07-28 17:40:40    4.0
# 29818     19997      "SORBET" Blood Orange  2018-07-28 17:40:40    2.5
# 29819     19998            "SORBET" Lychee  2018-07-28 18:21:44    3.0
# 29820     19998     "ICE CREAM" Rocky Road  2018-07-28 18:21:44    3.5
# 29821     19999      "SORBET" Blood Orange  2018-07-28 18:51:57    2.5
#
#        quantity  line_total
# 0             3        10.5
# 1             1         3.5
# ...

# %% [markdown]
# Sanity check for value ranges and to check assumption

# %%
df['price'].describe()
# Out:
# count    27624.000000
# mean         2.511711
# std          1.059244
# min          0.500000
# 25%          1.500000
# 50%          2.500000
# 75%          3.500000
# max          4.000000
# Name: price, dtype: float64

# %%
df['line_total'].describe()
# Out:
# count    27624.000000
# mean         5.028526
# std          3.085694
# min          0.000000
# 25%          2.500000
# 50%          4.500000
# 75%          7.500000
# max         12.000000
# Name: line_total, dtype: float64

# %%
df['name'].value_counts()
# Out:
# "ICE CREAM" Mint Chip             1088
# "SORBET" Lemon                    1087
# "ICE CREAM" Candied Bacon         1073
# "CONE" Sugar Cone                 1057
# "ICE CREAM" Double Fudge Chunk    1053
# "ICE CREAM" Rocky Road            1051
# "ICE CREAM" Dark Chocolate        1048
# "CONE" Cookie Cone                1045
# "SORBET" Raspberry                1044
# "CONE" Dipped Waffle Cone         1033
# "ICE CREAM" Maple Brown Sugar     1028
# "SORBET" Blood Orange             1027
# "BEVERAGE" Iced Coffee            1024
# "CONE" Brownie Cone               1023
# "ICE CREAM" Wildberry             1022
# "ICE CREAM" Dulce De Leche        1017
# "ICE CREAM" Matcha                1011
# "ICE CREAM" Vanilla Bean          1010
# "ICE CREAM" Strawberry            1009
# "BEVERAGE" Espresso               1002
# "SORBET" Lychee                    994
# "SORBET" Watermelon                994
# "ICE CREAM" Earl Gray              993
# "ICE CREAM" Peanut Fudge           983
# ...

# %% [markdown]
# 2.Job Market

# %% [markdown]
# Load the data using Pandas

# %%
df= pd.read_csv("/content/drive/MyDrive/Colab/job-market.csv")
df
# Out:
#                Id                                              Title  \
# 0      37404348.0                           Casual Stock Replenisher
# 1      37404337.0                           Casual Stock Replenisher
# 2      37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3      37404330.0                              Team member - Belrose
# 4      37404308.0  Business Banking Contact Centre Specialist, Ni...
# ...           ...                                                ...
# 40784         NaN                                                NaN
# 40785         NaN                                                NaN
# 40786         NaN                                                NaN
# 40787         NaN                                                NaN
# 40788         NaN                                                NaN
#
#                                               Company  \
# 0                                         Aldi Stores
# ...

# %% [markdown]
# Visualize top 10 first rows

# %%
df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %% [markdown]
# Fix column datatypes.

# %%
df.dtypes
# Out:
# Id                   float64
# Title                 object
# Company               object
# Date                  object
# Location              object
# Area                  object
# Classification        object
# SubClassification     object
# Requirement           object
# FullDescription       object
# LowestSalary         float64
# HighestSalary        float64
# JobType               object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# <ipython-input-248-a990aacd1078>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# Id                               float64
# Title                             object
# Company                           object
# Date                 datetime64[ns, UTC]
# Location                          object
# Area                              object
# Classification                    object
# SubClassification                 object
# Requirement                       object
# FullDescription                   object
# LowestSalary                     float64
# HighestSalary                    float64
# JobType                           object
# dtype: object

# %%
df = df.dropna()

# %%
df
# Out:
#                Id                                         Title  \
# 121    37404238.0                          Fabricator/Installer
# 122    37404195.0                                   Boilermaker
# 125    37404288.0  Casual Childcare Positions  | Bondi Junction
# 126    37404267.0                                    Technician
# 127    37404230.0                              Systems Engineer
# ...           ...                                           ...
# 10091  37388929.0                            Lead Kit Assembler
# 10094  37388912.0                           Executive Assistant
# 10096  37388901.0                  Receptionist / Administrator
# 10097  37388898.0     INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 10098  37388893.0               Customer Service Representative
#
#                            Company                      Date   Location  \
# 121      WORKPLACE ACCESS & SAFETY 2018-10-07 00:00:00+00:00  Melbourne
# ...

# %% [markdown]
# Check and clean the data
